# %%
#pip install music21

# %%
from music21 import note,stream
from music21 import *

# %%
#import music21
#music21.configure.run()

# %%
#treble clef
treble = clef.TrebleClef()
treble.sign
treble.show()

# %%
#bass clef
pc = clef.PitchClef()
pc.sign = 'F'
pc.line = 4
#pc.octaveChange = -1
pc.show()

# %%
n1 = note.Note('C4')
n1.show()

# %%
n2 = note.Note('C5')
n2.show()

# %%
#combine the notes for melody
s = stream.Stream() 
s.append(n1)
s.append(n2)
s.show()

# %%
#s.write('midi', fp='Test.midi')

# %%
n1 = note.Note('C4')
n1.show()
print(n1.quarterLength) #by default midi makes quarter notes
# Out:
# 1.0

# %%
n1.quarterLength =.5 #1/8 notes
n1.show()

# %%
n1.quarterLength = 2 #whole notes
n1.show()

# %%
n1 = note.Note('C', quarterLength = 4)#setting the measure in the note creation
n1.show()

# %%
#Let's create a melody
n1 = note.Note('C',quarterLength = 1)
n2 = note.Note('E',quarterLength = 0.5)
n3 = note.Note('G',quarterLength = 0.5)
n4 = note.Note('C',quarterLength = 2)


s = stream.Stream()
s.append([n1,n2,n3,n4])
s.show()

# %%
#s.write('midi', fp='FirstMelody.midi')

# %%
#Can I makde a melody on the bass clef?
n = note.Note('B2')
s = stream.Stream([n])
s.show()

# %%
#Let me see if i know how to sight read and chart the Lullaby music
#L
n1 = note.Note('A2',quarterLength = 1)
n2 = note.Note('A2',quarterLength = 1)
n3 = note.Note('B2',quarterLength = 1)
n4 = note.Note('A2',quarterLength = 1)
#R
n5 = note.Note('D',quarterLength = 1)
csharp1 = note.Note('C#4',quarterLength = 1)
#hb to you

#L
n7 = note.Note('A2',quarterLength = 1)
n8 = note.Note('A2',quarterLength = 1)
n9 = note.Note('B2',quarterLength = 1)
n10 = note.Note('A2',quarterLength = 1)
#R
n11 = note.Note('E',quarterLength = 1)
n12 = note.Note('D',quarterLength = 1)
#hb to you

#L
n13 = note.Note('A2',quarterLength = 1)
n14 = note.Note('A2',quarterLength = 1)
n15 = note.Note('A2',quarterLength = 1)
#R
fsharp1 = note.Note('F#4',quarterLength = 1)
n17 = note.Note('D',quarterLength = 1)
csharp2 = note.Note('C#4',quarterLength = 1)
#L
n19 = note.Note('B2',quarterLength =1)
#hb dear huamn

#R
n20 = note.Note('G',quarterLength = 1)
n21 = note.Note('G',quarterLength = 1)
fsharp2 = note.Note('F#4',quarterLength = 1)
n23 = note.Note('D',quarterLength = 1)
n24 = note.Note('E',quarterLength = 1)
n25 = note.Note('D',quarterLength = 1)
#hb to you.
s = stream.Stream()
s.append([n1,n2,n3,n4,n5,csharp1,n7,n8,n9,n10,
         n11,n12,n13,n14,n15,fsharp1,n17,csharp2,n19,
         n20,n21,fsharp2,n23,n24,n25])
s.show()

# %%
#s.write('midi', fp='Birthday2.midi')

# %%
Cb= note.Note('c-2')
Cb.show()

# %%
csharp = note.Note('C#4',quarterLength = 1)
csharp.name
csharp.show()

# %%
fsharp = note.Note('F#4',quarterLength = 1)
fsharp.name
fsharp.show()
